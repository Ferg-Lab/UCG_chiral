# %%
#### import os
import numpy as np
import pandas as pd
# import nglview as nv
import MDAnalysis as mda # NOTE -- version is 2.4 - not for processing traj (doesn't support nojump)
import MDAnalysis.transformations as tf
from MDAnalysis.analysis import distances
from MDAnalysis.lib import distances as lib_distances
import MDAnalysis.analysis.rms as rms
import pickle
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.ticker import MultipleLocator, AutoMinorLocator

import os
import string
# Out:
# /project2/andrewferguson/sivadasetty/doe/ucg/software/mscg/lib/python3.9/site-packages/Bio/Application/__init__.py:39: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(

# %%
print(mda.__version__)
# Out:
# 2.7.0

# %%
# plot settings
showPlots=1
useMagics=1
if useMagics:
    # %matplotlib inline
    #%matplotlib notebook
    # %load_ext autoreload
    # %autoreload 2
    # %reload_ext autoreload
    
font = {'weight' : 'normal',
        'size'   : 20}

plt.rc('font', **font)

# %% [markdown]
# ## Read AA and UCG RDF profiles

# %%
# ################################################################################################
# # Read AA RDF [See ../scripts/run_rdf.py  for calculation details]
# ################################################################################################
all_temperatures = [3.8]

# aa_RDF_max_6_density = {}
symm_aa_RDF_max_6_density = {}

for density in [0.07, 0.09, 0.11]:

    if density == 0.11:
        outpath = '/project2/andrewferguson/sivadasetty/doe/ucg/chiral_tetramer/SystemSize1000tetramers'
    else:
         outpath = '/project2/andrewferguson/sivadasetty/doe/ucg/chiral_tetramer/SystemSize1000tetramers_' + str(density)        
        
                
    # aa_RDF_max_6 = {}
    symm_aa_RDF_max_6 = {}
    for temperature in all_temperatures:
        aa_traj_file_path = outpath + '/T-'+str(temperature)+'_freqdouble_racemic/'
            
        symm_rdf_results_file_max_6 = aa_traj_file_path +  'chiral_results/symmetry_rdf_halfbox_maxbound_8_nbinary_REM.pkl'
        with open(symm_rdf_results_file_max_6, 'rb') as file:
            symm_aa_RDF_max_6[temperature] = pickle.load(file)

    # aa_RDF_max_6_density[density] = aa_RDF_max_6
    symm_aa_RDF_max_6_density[density] = symm_aa_RDF_max_6

# %%
all_nsteps = [50000]
all_chiral_lag = [50]

# %%
results_path_run = {}
for run in [1,2,3]:

    results_path_density = {}
    
    for density in [0.07, 0.09, 0.11]:
    
        path_to_density = '/project2/andrewferguson/sivadasetty/doe/ucg/notebooks/chiral/manuscript/simulations/rem/high-t-repeat-nneigh12-NR-Hess-7-EXTENDED/validation-density-lastiter-multiple-runs/density_'+str(density)
            
        results_path_temperature = {}
        for temperature in all_temperatures:
            results_path_temperature_nsteps = {}
            for nsteps in all_nsteps: 
                results_presults_path_temperature_nsteps_chiral_lag = {}
                for chiral_lag in all_chiral_lag: 
    
                    results_presults_path_temperature_nsteps_chiral_lag[chiral_lag] = path_to_density + '_t_'+str(temperature)+'_chiral_lag_'+str(chiral_lag)+'_nsteps_'+str(nsteps)+'/run' + str(run) + '/'
            
                results_path_temperature_nsteps[nsteps] = results_presults_path_temperature_nsteps_chiral_lag
            results_path_temperature[temperature] = results_path_temperature_nsteps
    
        results_path_density[density] = results_path_temperature

    results_path_run[run] = results_path_density

# %%
################################################################################################
# Read UCG RDF [See ../scripts/run_rdf.py  for calculation details]
################################################################################################
bi_ucg_RDF_max_6_run = {}
for run in [1,2,3]:
    bi_ucg_RDF_max_6_density = {}
    for density in [0.07, 0.09, 0.11]:
    
        bi_ucg_RDF_max_6_temperature = {}
        for temperature in all_temperatures:
            bi_ucg_RDF_max_6_temperature_nsteps = {}
            for nsteps in all_nsteps: 
                bi_ucg_RDF_max_6_temperature_nsteps_chiral_lag = {}
                for chiral_lag in all_chiral_lag:
                    bi_ucg_RDF_max_6_temperature_nsteps_chiral_lag_iter = {}
                    for i in range(1):
                        
                        ibi_target_folder = results_path_run[run][density][temperature][nsteps][chiral_lag] 
        
                        
                        rdf_results_file_max_6 = ibi_target_folder + '/' + 'symmetry_rdf_halfbox_maxbound_8_nbinary.pkl'
                        
                        if os.path.exists(rdf_results_file_max_6):
                            with open(rdf_results_file_max_6, 'rb') as file:
                                bi_ucg_RDF_max_6_temperature_nsteps_chiral_lag_iter[i] = pickle.load(file)
                    bi_ucg_RDF_max_6_temperature_nsteps_chiral_lag[chiral_lag] = bi_ucg_RDF_max_6_temperature_nsteps_chiral_lag_iter
                bi_ucg_RDF_max_6_temperature_nsteps[nsteps] = bi_ucg_RDF_max_6_temperature_nsteps_chiral_lag
            bi_ucg_RDF_max_6_temperature[temperature] = bi_ucg_RDF_max_6_temperature_nsteps
    
        bi_ucg_RDF_max_6_density[density] = bi_ucg_RDF_max_6_temperature

    bi_ucg_RDF_max_6_run[run] = bi_ucg_RDF_max_6_density

# %% [markdown]
# ## Read chiral counts

# %%
################################################################################################
# Read AA chiral count [See ../scripts/run_rdf.py  for calculation details]
################################################################################################

chiralcount_max_6_density = {}
bchiralcount_max_6_density = {}

for density in [0.07, 0.09, 0.11]:

    if density == 0.11:
        outpath = '/project2/andrewferguson/sivadasetty/doe/ucg/chiral_tetramer/SystemSize1000tetramers/'
    else:
        outpath = '/project2/andrewferguson/sivadasetty/doe/ucg/chiral_tetramer/SystemSize1000tetramers_'+str(density)+'/'

    chiralcount_max_6 = {}
    bchiralcount_max_6 = {}
    
    for temperature in all_temperatures:
        aa_traj_file_path = outpath + 'T-'+str(temperature)+'_freqdouble_racemic/'
        
        chiral_results_file_max_6 = aa_traj_file_path +  'chiral_results/count_ld_REM.pkl'
        with open(chiral_results_file_max_6, 'rb') as file:
            chiralcount_max_6[temperature] = pickle.load(file)

        bchiral_results_file_max_6 = aa_traj_file_path +  'chiral_results/count_ld.pkl'
        with open(bchiral_results_file_max_6, 'rb') as file:
            bchiralcount_max_6[temperature] = pickle.load(file)


    chiralcount_max_6_density[density] = chiralcount_max_6
    bchiralcount_max_6_density[density] = bchiralcount_max_6

# %%
bi_ucg_chiral_count_run = {}
for run in [1,2,3]:

    bi_ucg_chiral_count_density = {}
    for density in [0.07, 0.09, 0.11]:
    
        bi_ucg_chiral_count_temperature = {}
        for temperature in all_temperatures:
            bi_ucg_chiral_count_temperature_nsteps = {}
            for nsteps in all_nsteps:
                bi_ucg_chiral_count_temperature_chiral_lag = {}
                for chiral_lag in all_chiral_lag:
                    bi_ucg_chiral_count_temperature_iter = {}
                    for i in range(1):
                        
                        ibi_target_folder = results_path_run[run][density][temperature][nsteps][chiral_lag] 
                        
                        chiral_results_file_max_6 = ibi_target_folder + '/' + 'count_ld.pkl'
                        if os.path.exists(chiral_results_file_max_6):
                            with open(chiral_results_file_max_6, 'rb') as file:
                                bi_ucg_chiral_count_temperature_iter[i] = pickle.load(file)
                    
                    bi_ucg_chiral_count_temperature_chiral_lag[chiral_lag] = bi_ucg_chiral_count_temperature_iter
                    
                bi_ucg_chiral_count_temperature_nsteps[nsteps] = bi_ucg_chiral_count_temperature_chiral_lag
                
            bi_ucg_chiral_count_temperature[temperature] = bi_ucg_chiral_count_temperature_nsteps
    
        bi_ucg_chiral_count_density[density] = bi_ucg_chiral_count_temperature

    bi_ucg_chiral_count_run[run] = bi_ucg_chiral_count_density

# %%
# results_path_run[1][0.09][3.8][50000][50]

# %%
# aa_chiral_hist_density = {}
aa_ee_density = {}

for density in [0.07, 0.09, 0.11]:
    # aa_chiral_hist_temperature = {}
    aa_ee = {}
    for i, temperature in enumerate(all_temperatures):
        #l_hist, l_bin_edges = np.histogram(np.array(list(chiralcount_max_6_density[density][temperature]['l'].values())), bins=50, density=True)
        #d_hist, d_bin_edges = np.histogram(np.array(list(chiralcount_max_6_density[density][temperature]['d'].values())), bins=50, density=True)
        
        #l_bin_centers = 0.5 * (l_bin_edges[:-1] + l_bin_edges[1:])
        #d_bin_centers = 0.5 * (d_bin_edges[:-1] + d_bin_edges[1:])
        
        #aa_chiral_hist_temperature[temperature] = {'l_hist': l_hist, 'l_bin_edges': l_bin_edges, 'l_bin_centers': l_bin_centers,
        #                                           'd_hist': d_hist, 'd_bin_edges': d_bin_edges, 'd_bin_centers': d_bin_centers}
    
        skip=1
        numerator = np.array(list(chiralcount_max_6_density[density][temperature]['l'].values()))[::skip]-np.array(list(chiralcount_max_6_density[density][temperature]['d'].values()))[::skip]
        denominator = np.array(list(chiralcount_max_6_density[density][temperature]['l'].values()))[::skip]+np.array(list(chiralcount_max_6_density[density][temperature]['d'].values()))[::skip]
        aa_ee[temperature] = np.array(numerator)/np.array(denominator)

    #aa_chiral_hist_density[density] = aa_chiral_hist_temperature
    aa_ee_density[density] = aa_ee
    



#full_aa_chiral_hist_density = {}
full_aa_ee_density = {}

for density in [0.07, 0.09, 0.11]:
    #full_aa_chiral_hist_temperature = {}
    full_aa_ee = {}
    for i, temperature in enumerate(all_temperatures):
        #l_hist, l_bin_edges = np.histogram(np.array(list(bchiralcount_max_6_density[density][temperature]['l'].values())), bins=50, density=True)
        #d_hist, d_bin_edges = np.histogram(np.array(list(bchiralcount_max_6_density[density][temperature]['d'].values())), bins=50, density=True)
        
        #l_bin_centers = 0.5 * (l_bin_edges[:-1] + l_bin_edges[1:])
        #d_bin_centers = 0.5 * (d_bin_edges[:-1] + d_bin_edges[1:])
        
        #full_aa_chiral_hist_temperature[temperature] = {'l_hist': l_hist, 'l_bin_edges': l_bin_edges, 'l_bin_centers': l_bin_centers,
        #                                                'd_hist': d_hist, 'd_bin_edges': d_bin_edges, 'd_bin_centers': d_bin_centers}
    
        skip=1
        numerator = np.array(list(bchiralcount_max_6_density[density][temperature]['l'].values()))[::skip]-np.array(list(bchiralcount_max_6_density[density][temperature]['d'].values()))[::skip]
        denominator = np.array(list(bchiralcount_max_6_density[density][temperature]['l'].values()))[::skip]+np.array(list(bchiralcount_max_6_density[density][temperature]['d'].values()))[::skip]
        full_aa_ee[temperature] = np.array(numerator)/np.array(denominator)

    #full_aa_chiral_hist_density[density] = aa_chiral_hist_temperature
    full_aa_ee_density[density] = aa_ee
    



#bi_ucg_chiral_hist_run = {}
bi_ee_run = {}
for run in [1,2,3]:

    #bi_ucg_chiral_hist_density = {}
    bi_ee_density = {}
    for density in [0.07, 0.09, 0.11]:
    
        #bi_ucg_chiral_hist_temperature = {}
        bi_ee_temperature = {}
    
        for temperature in all_temperatures:
            #bi_ucg_chiral_hist_temperature_nsteps = {}
            bi_ee_temperature_nsteps = {}
        
            for nsteps in all_nsteps:
                #bi_ucg_chiral_hist_temperature_nsteps_chiral_lag = {}
                bi_ee_temperature_nsteps_chiral_lag = {}
                
                for chiral_lag in all_chiral_lag:
                    #bi_ucg_chiral_hist_temperature_nsteps_chiral_lag_iter = {}
                    bi_ee_temperature_nsteps_chiral_lag_iter = {}
                    
                    for i in bi_ucg_chiral_count_density[density][temperature][nsteps][chiral_lag].keys():
                        
                        #l_hist, l_bin_edges = np.histogram(np.array(list(bi_ucg_chiral_count_run[run][density][temperature][nsteps][chiral_lag][i]['l'].values())), bins=50, density=True)
                        #d_hist, d_bin_edges = np.histogram(np.array(list(bi_ucg_chiral_count_run[run][density][temperature][nsteps][chiral_lag][i]['d'].values())), bins=50, density=True)
                
                        #l_bin_centers = 0.5 * (l_bin_edges[:-1] + l_bin_edges[1:])
                        #d_bin_centers = 0.5 * (d_bin_edges[:-1] + d_bin_edges[1:])
                        
                        #bi_ucg_chiral_hist_temperature_nsteps_chiral_lag_iter[i] = {'l_hist': l_hist, 'l_bin_edges': l_bin_edges, 'l_bin_centers': l_bin_centers,
                        #                                                            'd_hist': d_hist, 'd_bin_edges': d_bin_edges, 'd_bin_centers': d_bin_centers}
        
                        skip=1
                        numerator = (np.array(list(bi_ucg_chiral_count_run[run][density][temperature][nsteps][chiral_lag][i]['l'].values()))[::skip]-np.array(list(bi_ucg_chiral_count_run[run][density][temperature][nsteps][chiral_lag][i]['d'].values()))[::skip])
                        denominator = (np.array(list(bi_ucg_chiral_count_run[run][density][temperature][nsteps][chiral_lag][i]['l'].values()))[::skip]+np.array(list(bi_ucg_chiral_count_run[run][density][temperature][nsteps][chiral_lag][i]['d'].values()))[::skip])
                        bi_ee_temperature_nsteps_chiral_lag_iter[i] = np.array(numerator)/np.array(denominator)
        
                    #bi_ucg_chiral_hist_temperature_nsteps_chiral_lag[chiral_lag] = bi_ucg_chiral_hist_temperature_nsteps_chiral_lag_iter
                    bi_ee_temperature_nsteps_chiral_lag[chiral_lag] = bi_ee_temperature_nsteps_chiral_lag_iter
        
                #bi_ucg_chiral_hist_temperature_nsteps[nsteps] = bi_ucg_chiral_hist_temperature_nsteps_chiral_lag
                bi_ee_temperature_nsteps[nsteps] = bi_ee_temperature_nsteps_chiral_lag
        
            #bi_ucg_chiral_hist_temperature[temperature] = bi_ucg_chiral_hist_temperature_nsteps
            bi_ee_temperature[temperature] = bi_ee_temperature_nsteps 
            
        #bi_ucg_chiral_hist_density[density] = bi_ucg_chiral_hist_temperature
        bi_ee_density[density] = bi_ee_temperature


    #bi_ucg_chiral_hist_run[run] = bi_ucg_chiral_hist_density
    bi_ee_run[run] = bi_ee_density

# %%
## Save ee

# %%
# # Fig3-4-AA-UCG-EE
# with open('Fig3-4-AA-UCG-EE/fig4-ee-ucg.pkl', 'wb') as file:
#     pickle.dump(bi_ee_run, file)

# # Fig3-4-AA-UCG-EE
# with open('Fig3-4-AA-UCG-EE/fig4-ee-aa.pkl', 'wb') as file:
#     pickle.dump(aa_ee_density, file)

# # Fig3-4-AA-UCG-EE
# with open('Fig3-4-AA-UCG-EE/fig4-ee-aa-full.pkl', 'wb') as file:
#     pickle.dump(full_aa_ee_density, file)

# %%
aa_ee_symmetry_hist_density = {}

for density in [0.07, 0.09, 0.11]:
    
    aa_ee_symmetry_hist_temperature = {}
    for i, temperature in enumerate(all_temperatures):
    
        aa_ee_symmetry = np.concatenate((aa_ee_density[density][temperature], -aa_ee_density[density][temperature]))
        aa_ee_symmetry_hist, aa_ee_symmetry_bin_edges = np.histogram(aa_ee_symmetry, bins=30, range=[-1,1], density=True)
        aa_ee_symmetry_bin_centers = 0.5 * (aa_ee_symmetry_bin_edges[:-1] + aa_ee_symmetry_bin_edges[1:])
        aa_ee_symmetry_hist_temperature[temperature] = {'ee_symmetry_hist': aa_ee_symmetry_hist, 'ee_symmetry_bin_edges': aa_ee_symmetry_bin_edges, 'ee_symmetry_bin_centers': aa_ee_symmetry_bin_centers}
        
    aa_ee_symmetry_hist_density[density] = aa_ee_symmetry_hist_temperature


bi_ee_symmetry_hist_run = {}
for run in [1,2,3]:
    
    bi_ee_symmetry_hist_density = {}

    for density in [0.07, 0.09, 0.11]:
        
        bi_ee_symmetry_hist_temperature = {}
        
        for temperature in all_temperatures:
            bi_ee_symmetry_hist_temperature_nsteps = {}
            
            for nsteps in all_nsteps:
                bi_ee_symmetry_hist_temperature_nsteps_chiral_lag = {}
                
                for chiral_lag in all_chiral_lag:
                    bi_ee_symmetry_hist_temperature_nsteps_chiral_lag_iter = {}
                    
                    for i in bi_ee_run[run][density][temperature][nsteps][chiral_lag].keys():
        
                        bi_ee_symmetry = np.concatenate((bi_ee_run[run][density][temperature][nsteps][chiral_lag][i], - bi_ee_run[run][density][temperature][nsteps][chiral_lag][i]))
    
                        
                        bi_ee_symmetry_hist, bi_ee_symmetry_bin_edges = np.histogram(bi_ee_symmetry, bins=30, range=[-1,1], density=True)
                        bi_ee_symmetry_bin_centers = 0.5 * (bi_ee_symmetry_bin_edges[:-1] + bi_ee_symmetry_bin_edges[1:])
                        bi_ee_symmetry_hist_temperature_nsteps_chiral_lag_iter[i] = {'ee_symmetry_hist': bi_ee_symmetry_hist, 'manual_ee_symmetry_bin_edges': bi_ee_symmetry_bin_edges, 'ee_symmetry_bin_centers': bi_ee_symmetry_bin_centers}
                    
                    bi_ee_symmetry_hist_temperature_nsteps_chiral_lag[chiral_lag] = bi_ee_symmetry_hist_temperature_nsteps_chiral_lag_iter
                    
                bi_ee_symmetry_hist_temperature_nsteps[nsteps] = bi_ee_symmetry_hist_temperature_nsteps_chiral_lag 
                
            bi_ee_symmetry_hist_temperature[temperature] = bi_ee_symmetry_hist_temperature_nsteps
    
        bi_ee_symmetry_hist_density[density] = bi_ee_symmetry_hist_temperature

    bi_ee_symmetry_hist_run[run] = bi_ee_symmetry_hist_density

# %% [markdown]
# ## PLOT

# %%
plot_temperatures = all_temperatures

# %% [markdown]
# ## Plot comparison of AA and UCG RDF and EE.

# %%
fig = plt.figure(figsize=(14, 6))
plt.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.35, hspace=0.4)

grid = GridSpec(2, 3)

colors=['green','green','green']

axs = []
for k, density in enumerate([0.11, 0.09, 0.07]):
    
    ax1 = plt.subplot(grid[0,k])
    axs.append(ax1)

    for i, temperature in enumerate(plot_temperatures):

        t1_rdfs_runs = []
        t12_rdfs_runs = []
        for run in [1, 2, 3]:
            t1_rdf = bi_ucg_RDF_max_6_run[run][density][temperature][50000][50][0]['t1']['rdf']*2
            t1_rdfs_runs.append(t1_rdf)
            t12_rdf = bi_ucg_RDF_max_6_run[run][density][temperature][50000][50][0]['t12']['rdf']
            t12_rdfs_runs.append(t12_rdf)
            
        t1_rdfs_runs = np.array(t1_rdfs_runs)   
        t1_mean_rdf = np.mean(t1_rdfs_runs, axis=0)
        t1_std_rdf  = np.std(t1_rdfs_runs, axis=0, ddof=1)
        t12_rdfs_runs = np.array(t12_rdfs_runs)   
        t12_mean_rdf = np.mean(t12_rdfs_runs, axis=0)
        t12_std_rdf  = np.std(t12_rdfs_runs, axis=0, ddof=1)
    
        ## HOMOCHIRAL
        ax1.plot(bi_ucg_RDF_max_6_run[1][density][temperature][50000][50][0]['t1']['bin_centers'], t1_mean_rdf, color='mediumblue', lw=3, label='UCG: HO')
        ax1.fill_between(bi_ucg_RDF_max_6_run[1][density][temperature][50000][50][0]['t1']['bin_centers'],
                         t1_mean_rdf - t1_std_rdf, t1_mean_rdf + t1_std_rdf, color='mediumblue', alpha=0.3)
        ax1.plot(symm_aa_RDF_max_6_density[density][temperature]['t1']['bin_centers'], symm_aa_RDF_max_6_density[density][temperature]['t1']['rdf']*2, color='mediumblue', ls=':', lw=3, label='AA: HO')

        ## HETEROCHIRAL
        ax1.plot(bi_ucg_RDF_max_6_run[1][density][temperature][50000][50][0]['t12']['bin_centers'], t12_mean_rdf, color='crimson', lw=3, label='UCG: HE')
        ax1.fill_between(bi_ucg_RDF_max_6_run[1][density][temperature][50000][50][0]['t12']['bin_centers'], 
                         t12_mean_rdf - t12_std_rdf, t12_mean_rdf + t12_std_rdf, color='crimson', alpha=0.3)

        ax1.plot(symm_aa_RDF_max_6_density[density][temperature]['t12']['bin_centers'], symm_aa_RDF_max_6_density[density][temperature]['t12']['rdf']*1, color='crimson', ls=':', lw=3, label='AA: HE')


        if k == 0:   
            ax1.set_ylabel("g(r)")
            ax1.legend(frameon=False, fontsize=11, ncol=1, loc='lower right')
            
        #ax1.text(-0.95, shift_temperature[i] + 0.45, r"$\rho$: " + str(density), fontsize=15, color="black")
        ax1.set_title(r"$\rho$: " + str(density), fontsize=15, color="black")
            #if i == 0:
        ax1.grid()
        ax1.set_xlabel("$r$")

        ax1.xaxis.set_major_locator(MultipleLocator(1))
        ax1.yaxis.set_major_locator(MultipleLocator(.5))
        ax1.xaxis.set_minor_locator(AutoMinorLocator(n=5))
        ax1.yaxis.set_minor_locator(AutoMinorLocator(n=5))
        ax1.set_ylim(0.,1.8)



for k, density in enumerate([0.11, 0.09, 0.07]):

    ax2 = plt.subplot(grid[1,k])
    axs.append(ax2)
    
    for i, temperature in enumerate(plot_temperatures):
    
        ee_hists_runs = []
        for run in [1, 2, 3]:
            h = bi_ee_symmetry_hist_run[run][density][temperature][50000][50][0]['ee_symmetry_hist']
            ee_hists_runs.append(h)
    
        ee_hists_runs = np.array(ee_hists_runs)   
        mean_hist = np.mean(ee_hists_runs, axis=0)
        std_hist  = np.std(ee_hists_runs, axis=0, ddof=1)
        
    
        # ax2.plot(bi_ee_symmetry_hist_density[density][temperature][50000][50][0]['ee_symmetry_bin_centers'],
        #          bi_ee_symmetry_hist_density[density][temperature][50000][50][0]['ee_symmetry_hist'] + shift_temperature[i], 
        #          c=colors[k], alpha=1., lw=3, label='UCG')

        ax2.plot(bi_ee_symmetry_hist_run[1][density][temperature][50000][50][0]['ee_symmetry_bin_centers'],
                 mean_hist, c='green', alpha=1., lw=3, label='UCG')
        ax2.fill_between(bi_ee_symmetry_hist_run[1][density][temperature][50000][50][0]['ee_symmetry_bin_centers'],
                         mean_hist - std_hist, mean_hist + std_hist, color='green', alpha=0.3)

        ax2.plot(aa_ee_symmetry_hist_density[density][temperature]['ee_symmetry_bin_centers'], 
                 aa_ee_symmetry_hist_density[density][temperature]['ee_symmetry_hist'], 
                 c='black', lw=3, label='AA', ls=':')
    

        if k == 0:   
            ax2.set_ylabel("P(ee)")
            ax2.legend(frameon=False, fontsize=12)
                
        ax2.set_xlabel("ee")
    

        ax2.xaxis.set_major_locator(MultipleLocator(.5))
        ax2.yaxis.set_major_locator(MultipleLocator(1))
        ax2.xaxis.set_minor_locator(AutoMinorLocator(n=5))
        ax2.yaxis.set_minor_locator(AutoMinorLocator(n=5))
        ax2.set_ylim(0.,6)
        ax2.grid()

# # #####################################################################################
for i, ax in enumerate(axs):
    ax.text(-0.22, 1.2, '(' + string.ascii_lowercase[i] + ')', transform=ax.transAxes, size=23, weight='normal', va='top', ha='center')

# %%
# bi_ee_run[1][0.09]

# %% [markdown]
# ## For snapshots

# %%
density = 0.11
bi_ee_run[1][density][3.8][50000][50][0][244]
# Out:
# 0.8

# %%
np.argwhere( (np.abs(bi_ee_run[1][density][3.8][50000][50][0])  < 0.801) & (np.abs(bi_ee_run[1][density][3.8][50000][50][0])  > 0.799) )
# Out:
# array([[244],
#        [283],
#        [302],
#        [359],
#        [433],
#        [468],
#        [475]])

# %%
# np.argwhere( (np.abs(aa_ee_density[0.09][3.8])  > 0.499) & (np.abs(aa_ee_density[0.09][3.8])  < 0.501) )

# %%
density = 0.11
aa_ee_density[density][3.8]
# Out:
# array([-0.022,  0.072,  0.216,  0.146,  0.304,  0.634,  0.832,  0.866,
#         0.802,  0.856,  0.878,  0.838,  0.804,  0.828,  0.84 ,  0.878,
#         0.832,  0.796,  0.814,  0.784,  0.888,  0.852,  0.852,  0.882,
#         0.814,  0.866,  0.854,  0.852,  0.832,  0.832,  0.856,  0.802,
#         0.816,  0.828,  0.88 ,  0.856,  0.796,  0.804,  0.832,  0.794,
#         0.836,  0.858,  0.858,  0.87 ,  0.846,  0.846,  0.856,  0.846,
#         0.856,  0.796,  0.832,  0.8  ,  0.884,  0.87 ,  0.856,  0.838,
#         0.846,  0.874,  0.854,  0.832,  0.828,  0.822,  0.856,  0.836,
#         0.862,  0.824,  0.854,  0.824,  0.864,  0.848,  0.838,  0.846,
#         0.862,  0.832,  0.836,  0.86 ,  0.84 ,  0.82 ,  0.84 ,  0.816,
#         0.794,  0.848,  0.824,  0.82 ,  0.86 ,  0.82 ,  0.84 ,  0.808,
#         0.828,  0.808,  0.866,  0.87 ,  0.852,  0.816,  0.866,  0.898,
#         0.836,  0.828,  0.864,  0.856,  0.848,  0.83 ,  0.88 ,  0.868,
#         0.85 ,  0.806,  0.828,  0.822,  0.836,  0.828,  0.774,  0.848,
#         0.836,  0.83 ,  0.854,  0.846,  0.9  ,  0.83 ,  0.84 ,  0.868,
#         0.842,  0.822,  0.818,  0.832,  0.804,  0.826,  0.856,  0.822,
#         0.886,  0.874,  0.834,  0.852,  0.85 ,  0.776,  0.818,  0.854,
#         0.86 ,  0.83 ,  0.818,  0.858,  0.86 ,  0.806,  0.828,  0.858,
#         0.832,  0.842,  0.864,  0.814,  0.802,  0.876,  0.822,  0.832,
#         0.888,  0.872,  0.82 ,  0.808,  0.826,  0.848,  0.896,  0.816,
#         0.82 ,  0.822,  0.858,  0.87 ,  0.882,  0.804,  0.876,  0.83 ,
#         0.82 ,  0.834,  0.866,  0.848,  0.842,  0.858,  0.86 ,  0.864,
#         0.812,  0.84 ,  0.834,  0.846,  0.862,  0.816,  0.858,  0.804,
#         0.832,  0.84 ,  0.854,  0.854,  0.834,  0.874,  0.848,  0.868,
#         0.812,  0.872,  0.858,  0.81 ,  0.828,  0.842,  0.856,  0.88 ,
#         0.852,  0.89 ,  0.85 ,  0.858,  0.834,  0.81 ,  0.848,  0.848,
#         0.848,  0.812,  0.822,  0.84 ,  0.85 ,  0.87 ,  0.856,  0.858,
#         0.846,  0.776,  0.848,  0.842,  0.856,  0.854,  0.866,  0.844,
#         0.892,  0.85 ,  0.842,  0.876,  0.784,  0.86 ,  0.844,  0.82 ,
#         0.882,  0.84 ,  0.802,  0.796,  0.792,  0.806,  0.812,  0.868,
#         0.782,  0.836,  0.808,  0.838,  0.75 ,  0.864,  0.84 ,  0.82 ,
#         0.894,  0.858,  0.872,  0.818,  0.818,  0.866,  0.772,  0.868,
#         0.812,  0.838,  0.814,  0.832,  0.894,  0.878])

# %%
np.argwhere( (np.abs(aa_ee_density[density][3.8])  < 0.01) & (np.abs(aa_ee_density[density][3.8])  > 0.01) )
